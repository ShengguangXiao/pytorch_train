# %%
import math, os
import numpy as np
import h5py
import matplotlib.pyplot as plt
import scipy
from PIL import Image
from scipy import ndimage
import torch
import torch.nn as nn
from cnn_utils import *
from torch import nn,optim
from torch.utils.data import DataLoader,Dataset
from torchvision import transforms
from ClassicNetwork.AlexNet import AlexNet

# %%
np.random.seed(1)
torch.manual_seed(1)
batch_size = 64
learning_rate = 0.008
num_epocher = 50
pre_epoch = 0

# %%
rmb_label = {"class_good": 0, "class_bad": 1}

class MyData(Dataset):
    @staticmethod
    def get_img_info(data_dir):
        data_info = list()
        # data_dir 是训练集、验证集或者测试集的路径
        for root, dirs, _ in os.walk(data_dir):
            # 遍历类别
            # dirs ['1', '100']
            for sub_dir in dirs:
                # 文件列表
                img_names = os.listdir(os.path.join(root, sub_dir))
                # 取出 jpg 结尾的文件
                img_names = list(filter(lambda x: x.endswith('.png'), img_names))
                # 遍历图片
                for i in range(len(img_names)):
                    img_name = img_names[i]
                    # 图片的绝对路径
                    path_img = os.path.join(root, sub_dir, img_name)
                    print(path_img)
                    # 标签，这里需要映射为 0、1 两个类别
                    label = rmb_label[sub_dir]
                    # 保存在 data_info 变量中
                    data_info.append((path_img, int(label)))
        return data_info

    def __init__(self, data_dir, transform=None):
        """
        rmb面额分类任务的Dataset
        :param data_dir: str, 数据集所在路径
        :param transform: torch.transform，数据预处理
        """
        # data_info存储所有图片路径和标签，在DataLoader中通过index读取样本
        self.data_info = self.get_img_info(data_dir)
        self.transform = transform
    
    def __len__(self):
        return len(self.data_info)

    def __getitem__(self, index):
        # 通过 index 读取样本
        path_img, label = self.data_info[index]
        # 注意这里需要 convert('RGB')
        img = Image.open(path_img).convert('RGB')     # 0~255
        if self.transform is not None:
            img = self.transform(img)   # 在这里做transform，转为tensor等等
        # 返回是样本和标签
        return img, label

# %%
train_dir = './OcvData_Alex/Train_Set'
valid_dir = './OcvData_Alex/Valid_Set'
train_data = MyData(data_dir=train_dir, transform=transforms.ToTensor())
valid_data = MyData(data_dir=valid_dir, transform=transforms.ToTensor())
# Out:
# ./OcvData_Alex/Train_Set/class_bad/bad_image_4.png
# ./OcvData_Alex/Train_Set/class_bad/bad_image_5.png
# ./OcvData_Alex/Train_Set/class_bad/bad_image_7.png
# ./OcvData_Alex/Train_Set/class_bad/bad_image_6.png
# ./OcvData_Alex/Train_Set/class_bad/bad_image_2.png
# ./OcvData_Alex/Train_Set/class_bad/bad_image_3.png
# ./OcvData_Alex/Train_Set/class_bad/bad_image_1.png
# ./OcvData_Alex/Train_Set/class_bad/bad_image_8.png
# ./OcvData_Alex/Train_Set/class_good/good_image_8.png
# ./OcvData_Alex/Train_Set/class_good/good_image_1.png
# ./OcvData_Alex/Train_Set/class_good/good_image_3.png
# ./OcvData_Alex/Train_Set/class_good/good_image_2.png
# ./OcvData_Alex/Train_Set/class_good/good_image_6.png
# ./OcvData_Alex/Train_Set/class_good/good_image_7.png
# ./OcvData_Alex/Train_Set/class_good/good_image_5.png
# ./OcvData_Alex/Train_Set/class_good/good_image_4.png
# ./OcvData_Alex/Valid_Set/class_bad/bad_image_2.png
# ./OcvData_Alex/Valid_Set/class_bad/bad_image_1.png
# ./OcvData_Alex/Valid_Set/class_good/good_image_1.png
# ./OcvData_Alex/Valid_Set/class_good/good_image_2.png

# %%
# 构建DataLoder
# 其中训练集设置 shuffle=True，表示每个 Epoch 都打乱样本
train_loader = DataLoader(dataset=train_data, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(dataset=valid_data, batch_size=batch_size, shuffle=False)

# %%
device = 'cpu'

def test():
    model.eval()    #需要说明是否模型测试
    eval_loss = 0
    eval_acc = 0
    for data in valid_loader:
        img,label = data
        img = img.float().to(device)
        label = label.long().to(device)
        out = model(img)    #前向算法
        loss = criterion(out,label) #计算loss
        eval_loss += loss.item() * label.size(0)    #total loss
        _,pred = torch.max(out,1)   #预测结果
        num_correct = (pred == label).sum() #正确结果
        eval_acc += num_correct.item()  #正确结果总数

    print('Test Loss:{:.6f}, Acc: {:.6f}'
          .format(eval_loss/ (len(valid_data)),eval_acc * 1.0/(len(valid_data))))

    acc = eval_acc * 1.0/(len(valid_data))
    return acc

# %%
##### import model
# model = ResModel(6)
model = AlexNet(num_classes=len(rmb_label))
model = model.to(device)
criterion = nn.CrossEntropyLoss()
# optimizer = optim.Adam(model.parameters(), lr=learning_rate) # Adam doesn't have momentum
optimizer = optim.SGD(model.parameters(), lr=learning_rate, momentum=0.8)

# %%
last = 0.9
pth = './Resnet91.44epoch42.pt'

# %%
for epoch in range(pre_epoch, num_epocher):
    model.train()
    running_loss = 0.0
    running_acc = 0.0
    for i,data in enumerate(train_loader,1):
        img,label = data
        img = img.float().to(device)
        label = label.long().to(device)
        #前向传播
        out = model(img)
        loss = criterion(out,label) #loss
        running_loss += loss.item() * label.size(0)
        _,pred = torch.max(out,1)   #预测结果
        num_correct = (pred == label).sum() #正确结果的数量
        running_acc += num_correct.item()   #正确结果的总数
        
        optimizer.zero_grad()   #梯度清零
        loss.backward() #后向传播计算梯度
        optimizer.step()    #利用梯度更新W，b参数
    #打印一个循环后，训练集合上的loss和正确率
    if (epoch+1) % 1 == 0:
        print('Train{} epoch, Loss: {:.6f}, Acc: {:.6f}'.format(epoch+1,running_loss / (len(train_data)),
                                                               running_acc / (len(train_data))))
        now = test()

    ## save model
    # if epoch == 0:
    #     state = {'model':model.state_dict(), 'optimizer':optimizer.state_dict(), 'epoch':epoch}
    #     torch.save(state, './Resnet'+str(int(now*10000)/100)+'epoch'+str(epoch)+'.pt')
    #     last = now
    
    if now > last:
        state = {'model':model.state_dict(), 'optimizer':optimizer.state_dict(), 'epoch':epoch}
        torch.save(state, './Results/Alexnet_'+str(int(now*10000)/100)+'_epoch_'+str(epoch)+'.pt')
        last = now
        
        # example = torch.rand(1, 3, 47, 41)
        # traced_script_module = torch.jit.trace(model, example)
        # traced_script_module.save("traced_resnet_model.pt")
# Out:
# Train1 epoch, Loss: 0.693134, Acc: 0.500000
# Test Loss:0.693102, Acc: 0.500000
# Train2 epoch, Loss: 0.693360, Acc: 0.500000
# Test Loss:0.693098, Acc: 0.500000
# Train3 epoch, Loss: 0.693266, Acc: 0.500000
# Test Loss:0.693093, Acc: 0.500000
# Train4 epoch, Loss: 0.693271, Acc: 0.500000
# Test Loss:0.693085, Acc: 0.500000
# Train5 epoch, Loss: 0.693906, Acc: 0.500000
# Test Loss:0.693077, Acc: 0.500000
# Train6 epoch, Loss: 0.692901, Acc: 0.500000
# Test Loss:0.693068, Acc: 0.500000
# Train7 epoch, Loss: 0.692410, Acc: 0.500000
# Test Loss:0.693059, Acc: 0.500000
# Train8 epoch, Loss: 0.692834, Acc: 0.500000
# Test Loss:0.693049, Acc: 0.500000
# Train9 epoch, Loss: 0.692424, Acc: 0.437500
# Test Loss:0.693040, Acc: 0.500000
# Train10 epoch, Loss: 0.693219, Acc: 0.500000
# Test Loss:0.693029, Acc: 0.500000
# Train11 epoch, Loss: 0.693281, Acc: 0.500000
# Test Loss:0.693018, Acc: 0.500000
# Train12 epoch, Loss: 0.692960, Acc: 0.500000
# Test Loss:0.693008, Acc: 0.500000
# Train13 epoch, Loss: 0.692813, Acc: 0.437500
# Test Loss:0.692997, Acc: 0.500000
# Train14 epoch, Loss: 0.693200, Acc: 0.500000
# Test Loss:0.692987, Acc: 0.500000
# Train15 epoch, Loss: 0.693335, Acc: 0.562500
# Test Loss:0.692976, Acc: 0.500000
# Train16 epoch, Loss: 0.692607, Acc: 0.625000
# Test Loss:0.692966, Acc: 0.500000
# Train17 epoch, Loss: 0.692960, Acc: 0.500000
# Test Loss:0.692956, Acc: 0.500000
# Train18 epoch, Loss: 0.693019, Acc: 0.562500
# Test Loss:0.692945, Acc: 0.500000
# Train19 epoch, Loss: 0.693293, Acc: 0.500000
# Test Loss:0.692935, Acc: 0.500000
# Train20 epoch, Loss: 0.693000, Acc: 0.500000
# Test Loss:0.692924, Acc: 0.500000
# Train21 epoch, Loss: 0.692459, Acc: 0.500000
# Test Loss:0.692912, Acc: 0.500000
# Train22 epoch, Loss: 0.693110, Acc: 0.500000
# Test Loss:0.692901, Acc: 0.500000
# Train23 epoch, Loss: 0.692495, Acc: 0.625000
# Test Loss:0.692890, Acc: 0.500000
# Train24 epoch, Loss: 0.692562, Acc: 0.562500
# Test Loss:0.692879, Acc: 0.500000
# Train25 epoch, Loss: 0.693073, Acc: 0.437500
# Test Loss:0.692868, Acc: 0.500000
# Train26 epoch, Loss: 0.692263, Acc: 0.625000
# Test Loss:0.692858, Acc: 0.500000
# Train27 epoch, Loss: 0.693402, Acc: 0.375000
# Test Loss:0.692847, Acc: 0.500000
# Train28 epoch, Loss: 0.693365, Acc: 0.562500
# Test Loss:0.692837, Acc: 0.500000
# Train29 epoch, Loss: 0.692988, Acc: 0.500000
# Test Loss:0.692827, Acc: 0.500000
# Train30 epoch, Loss: 0.692418, Acc: 0.687500
# Test Loss:0.692817, Acc: 0.500000
# Train31 epoch, Loss: 0.692904, Acc: 0.625000
# Test Loss:0.692806, Acc: 0.500000
# Train32 epoch, Loss: 0.692340, Acc: 0.687500
# Test Loss:0.692795, Acc: 0.500000
# Train33 epoch, Loss: 0.693287, Acc: 0.500000
# Test Loss:0.692784, Acc: 0.500000
# Train34 epoch, Loss: 0.692246, Acc: 0.625000
# Test Loss:0.692773, Acc: 0.500000
# Train35 epoch, Loss: 0.693044, Acc: 0.562500
# Test Loss:0.692763, Acc: 0.750000
# Train36 epoch, Loss: 0.692398, Acc: 0.625000
# Test Loss:0.692752, Acc: 0.750000
# Train37 epoch, Loss: 0.692474, Acc: 0.687500
# Test Loss:0.692741, Acc: 0.750000
# Train38 epoch, Loss: 0.692460, Acc: 0.562500
# Test Loss:0.692731, Acc: 0.750000
# Train39 epoch, Loss: 0.693023, Acc: 0.562500
# Test Loss:0.692720, Acc: 0.750000
# Train40 epoch, Loss: 0.692662, Acc: 0.687500
# Test Loss:0.692710, Acc: 0.750000
# Train41 epoch, Loss: 0.693564, Acc: 0.500000
# Test Loss:0.692701, Acc: 0.750000
# Train42 epoch, Loss: 0.692834, Acc: 0.625000
# Test Loss:0.692690, Acc: 0.750000
# Train43 epoch, Loss: 0.692733, Acc: 0.562500
# Test Loss:0.692680, Acc: 0.750000
# Train44 epoch, Loss: 0.693057, Acc: 0.437500
# Test Loss:0.692669, Acc: 1.000000
# Train45 epoch, Loss: 0.693164, Acc: 0.500000
# Test Loss:0.692659, Acc: 1.000000
# Train46 epoch, Loss: 0.692213, Acc: 0.562500
# Test Loss:0.692648, Acc: 1.000000
# Train47 epoch, Loss: 0.693346, Acc: 0.437500
# Test Loss:0.692637, Acc: 1.000000
# Train48 epoch, Loss: 0.692577, Acc: 0.625000
# Test Loss:0.692627, Acc: 1.000000
# Train49 epoch, Loss: 0.692236, Acc: 0.687500
# Test Loss:0.692616, Acc: 1.000000
# Train50 epoch, Loss: 0.692361, Acc: 0.750000
# Test Loss:0.692605, Acc: 1.000000

# %%
import math, os
import numpy as np
import h5py
import matplotlib.pyplot as plt
import scipy
from PIL import Image
from scipy import ndimage
import torch
import torch.nn as nn
from cnn_utils import *
from torch import nn,optim
from torch.utils.data import DataLoader,Dataset
from torchvision import transforms
from ClassicNetwork.AlexNet import AlexNet

# %%
np.random.seed(1)
torch.manual_seed(1)
batch_size = 64
learning_rate = 0.008
num_epocher = 50
pre_epoch = 0

# %%
rmb_label = {"class_good": 0, "class_bad": 1}

class MyData(Dataset):
    @staticmethod
    def get_img_info(data_dir):
        data_info = list()
        # data_dir 是训练集、验证集或者测试集的路径
        for root, dirs, _ in os.walk(data_dir):
            # 遍历类别
            # dirs ['1', '100']
            for sub_dir in dirs:
                # 文件列表
                img_names = os.listdir(os.path.join(root, sub_dir))
                # 取出 jpg 结尾的文件
                img_names = list(filter(lambda x: x.endswith('.png'), img_names))
                # 遍历图片
                for i in range(len(img_names)):
                    img_name = img_names[i]
                    # 图片的绝对路径
                    path_img = os.path.join(root, sub_dir, img_name)
                    print(path_img)
                    # 标签，这里需要映射为 0、1 两个类别
                    label = rmb_label[sub_dir]
                    # 保存在 data_info 变量中
                    data_info.append((path_img, int(label)))
        return data_info

    def __init__(self, data_dir, transform=None):
        """
        rmb面额分类任务的Dataset
        :param data_dir: str, 数据集所在路径
        :param transform: torch.transform，数据预处理
        """
        # data_info存储所有图片路径和标签，在DataLoader中通过index读取样本
        self.data_info = self.get_img_info(data_dir)
        self.transform = transform
    
    def __len__(self):
        return len(self.data_info)

    def __getitem__(self, index):
        # 通过 index 读取样本
        path_img, label = self.data_info[index]
        # 注意这里需要 convert('RGB')
        img = Image.open(path_img).convert('RGB')     # 0~255
        if self.transform is not None:
            img = self.transform(img)   # 在这里做transform，转为tensor等等
        # 返回是样本和标签
        return img, label

# %%
train_dir = './OcvData_Alex/Train_Set'
valid_dir = './OcvData_Alex/Valid_Set'
train_data = MyData(data_dir=train_dir, transform=transforms.ToTensor())
valid_data = MyData(data_dir=valid_dir, transform=transforms.ToTensor())
# Out:
# ./OcvData_Alex/Train_Set/class_bad/bad_image_4.png
# ./OcvData_Alex/Train_Set/class_bad/bad_image_5.png
# ./OcvData_Alex/Train_Set/class_bad/bad_image_7.png
# ./OcvData_Alex/Train_Set/class_bad/bad_image_6.png
# ./OcvData_Alex/Train_Set/class_bad/bad_image_2.png
# ./OcvData_Alex/Train_Set/class_bad/bad_image_3.png
# ./OcvData_Alex/Train_Set/class_bad/bad_image_1.png
# ./OcvData_Alex/Train_Set/class_bad/bad_image_8.png
# ./OcvData_Alex/Train_Set/class_good/good_image_8.png
# ./OcvData_Alex/Train_Set/class_good/good_image_1.png
# ./OcvData_Alex/Train_Set/class_good/good_image_3.png
# ./OcvData_Alex/Train_Set/class_good/good_image_2.png
# ./OcvData_Alex/Train_Set/class_good/good_image_6.png
# ./OcvData_Alex/Train_Set/class_good/good_image_7.png
# ./OcvData_Alex/Train_Set/class_good/good_image_5.png
# ./OcvData_Alex/Train_Set/class_good/good_image_4.png
# ./OcvData_Alex/Valid_Set/class_bad/bad_image_2.png
# ./OcvData_Alex/Valid_Set/class_bad/bad_image_1.png
# ./OcvData_Alex/Valid_Set/class_good/good_image_1.png
# ./OcvData_Alex/Valid_Set/class_good/good_image_2.png

# %%
# 构建DataLoder
# 其中训练集设置 shuffle=True，表示每个 Epoch 都打乱样本
train_loader = DataLoader(dataset=train_data, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(dataset=valid_data, batch_size=batch_size, shuffle=False)

# %%
device = 'cpu'

def test():
    model.eval()    #需要说明是否模型测试
    eval_loss = 0
    eval_acc = 0
    for data in valid_loader:
        img,label = data
        img = img.float().to(device)
        label = label.long().to(device)
        out = model(img)    #前向算法
        loss = criterion(out,label) #计算loss
        eval_loss += loss.item() * label.size(0)    #total loss
        _,pred = torch.max(out,1)   #预测结果
        num_correct = (pred == label).sum() #正确结果
        eval_acc += num_correct.item()  #正确结果总数

    print('Test Loss:{:.6f}, Acc: {:.6f}'
          .format(eval_loss/ (len(valid_data)),eval_acc * 1.0/(len(valid_data))))

    acc = eval_acc * 1.0/(len(valid_data))
    return acc

# %%
##### import model
# model = ResModel(6)
model = AlexNet(num_classes=len(rmb_label))
model = model.to(device)
criterion = nn.CrossEntropyLoss()
# optimizer = optim.Adam(model.parameters(), lr=learning_rate) # Adam doesn't have momentum
optimizer = optim.SGD(model.parameters(), lr=learning_rate, momentum=0.8)

# %%
last = 0.9
pth = './Resnet91.44epoch42.pt'

# %%
for epoch in range(pre_epoch, num_epocher):
    model.train()
    running_loss = 0.0
    running_acc = 0.0
    for i,data in enumerate(train_loader,1):
        img,label = data
        img = img.float().to(device)
        label = label.long().to(device)
        #前向传播
        out = model(img)
        loss = criterion(out,label) #loss
        running_loss += loss.item() * label.size(0)
        _,pred = torch.max(out,1)   #预测结果
        num_correct = (pred == label).sum() #正确结果的数量
        running_acc += num_correct.item()   #正确结果的总数
        
        optimizer.zero_grad()   #梯度清零
        loss.backward() #后向传播计算梯度
        optimizer.step()    #利用梯度更新W，b参数
    #打印一个循环后，训练集合上的loss和正确率
    if (epoch+1) % 1 == 0:
        print('Train{} epoch, Loss: {:.6f}, Acc: {:.6f}'.format(epoch+1,running_loss / (len(train_data)),
                                                               running_acc / (len(train_data))))
        now = test()

    ## save model
    # if epoch == 0:
    #     state = {'model':model.state_dict(), 'optimizer':optimizer.state_dict(), 'epoch':epoch}
    #     torch.save(state, './Resnet'+str(int(now*10000)/100)+'epoch'+str(epoch)+'.pt')
    #     last = now
    
    if now > last:
        state = {'model':model.state_dict(), 'optimizer':optimizer.state_dict(), 'epoch':epoch}
        torch.save(state, './Results/Alexnet_'+str(int(now*10000)/100)+'_epoch_'+str(epoch)+'.pt')
        last = now
        
        # example = torch.rand(1, 3, 47, 41)
        # traced_script_module = torch.jit.trace(model, example)
        # traced_script_module.save("traced_resnet_model.pt")
# Out:
# Train1 epoch, Loss: 0.693134, Acc: 0.500000
# Test Loss:0.693103, Acc: 0.500000
# Train2 epoch, Loss: 0.693361, Acc: 0.500000
# Test Loss:0.693101, Acc: 0.500000
# Train3 epoch, Loss: 0.693269, Acc: 0.500000
# Test Loss:0.693097, Acc: 0.500000
# Train4 epoch, Loss: 0.693276, Acc: 0.500000
# Test Loss:0.693093, Acc: 0.500000
# Train5 epoch, Loss: 0.693913, Acc: 0.500000
# Test Loss:0.693088, Acc: 0.500000
# Train6 epoch, Loss: 0.692909, Acc: 0.500000
# Test Loss:0.693082, Acc: 0.500000
# Train7 epoch, Loss: 0.692420, Acc: 0.500000
# Test Loss:0.693076, Acc: 0.500000
# Train8 epoch, Loss: 0.692847, Acc: 0.500000
# Test Loss:0.693070, Acc: 0.500000
# Train9 epoch, Loss: 0.692442, Acc: 0.500000
# Test Loss:0.693063, Acc: 0.500000
# Train10 epoch, Loss: 0.693240, Acc: 0.500000
# Test Loss:0.693057, Acc: 0.500000
# Train11 epoch, Loss: 0.693306, Acc: 0.500000
# Test Loss:0.693050, Acc: 0.500000
# Train12 epoch, Loss: 0.692982, Acc: 0.500000
# Test Loss:0.693044, Acc: 0.500000
# Train13 epoch, Loss: 0.692855, Acc: 0.500000
# Test Loss:0.693037, Acc: 0.500000
# Train14 epoch, Loss: 0.693236, Acc: 0.500000
# Test Loss:0.693030, Acc: 0.500000
# Train15 epoch, Loss: 0.693375, Acc: 0.500000
# Test Loss:0.693023, Acc: 0.500000
# Train16 epoch, Loss: 0.692663, Acc: 0.625000
# Test Loss:0.693016, Acc: 0.500000
# Train17 epoch, Loss: 0.693011, Acc: 0.500000
# Test Loss:0.693009, Acc: 0.500000
# Train18 epoch, Loss: 0.693061, Acc: 0.500000
# Test Loss:0.693002, Acc: 0.500000
# Train19 epoch, Loss: 0.693375, Acc: 0.500000
# Test Loss:0.692994, Acc: 0.500000
# Train20 epoch, Loss: 0.693047, Acc: 0.500000
# Test Loss:0.692987, Acc: 0.500000
# Train21 epoch, Loss: 0.692545, Acc: 0.500000
# Test Loss:0.692980, Acc: 0.500000
# Train22 epoch, Loss: 0.693166, Acc: 0.500000
# Test Loss:0.692972, Acc: 0.500000
# Train23 epoch, Loss: 0.692579, Acc: 0.500000
# Test Loss:0.692965, Acc: 0.500000
# Train24 epoch, Loss: 0.692643, Acc: 0.625000
# Test Loss:0.692958, Acc: 0.500000
# Train25 epoch, Loss: 0.693135, Acc: 0.500000
# Test Loss:0.692951, Acc: 0.500000
# Train26 epoch, Loss: 0.692336, Acc: 0.500000
# Test Loss:0.692944, Acc: 0.500000
# Train27 epoch, Loss: 0.693495, Acc: 0.375000
# Test Loss:0.692937, Acc: 0.500000
# Train28 epoch, Loss: 0.693423, Acc: 0.562500
# Test Loss:0.692931, Acc: 0.500000
# Train29 epoch, Loss: 0.693077, Acc: 0.500000
# Test Loss:0.692924, Acc: 0.500000
# Train30 epoch, Loss: 0.692526, Acc: 0.562500
# Test Loss:0.692917, Acc: 0.500000
# Train31 epoch, Loss: 0.692991, Acc: 0.500000
# Test Loss:0.692910, Acc: 0.500000
# Train32 epoch, Loss: 0.692492, Acc: 0.625000
# Test Loss:0.692902, Acc: 0.500000
# Train33 epoch, Loss: 0.693379, Acc: 0.437500
# Test Loss:0.692895, Acc: 0.500000
# Train34 epoch, Loss: 0.692351, Acc: 0.562500
# Test Loss:0.692889, Acc: 0.500000
# Train35 epoch, Loss: 0.693143, Acc: 0.437500
# Test Loss:0.692882, Acc: 0.500000
# Train36 epoch, Loss: 0.692538, Acc: 0.500000
# Test Loss:0.692875, Acc: 0.500000
# Train37 epoch, Loss: 0.692577, Acc: 0.625000
# Test Loss:0.692868, Acc: 0.500000
# Train38 epoch, Loss: 0.692597, Acc: 0.562500
# Test Loss:0.692861, Acc: 0.500000
# Train39 epoch, Loss: 0.693168, Acc: 0.562500
# Test Loss:0.692854, Acc: 0.500000
# Train40 epoch, Loss: 0.692777, Acc: 0.625000
# Test Loss:0.692847, Acc: 0.500000
# Train41 epoch, Loss: 0.693685, Acc: 0.375000
# Test Loss:0.692841, Acc: 0.500000
# Train42 epoch, Loss: 0.692973, Acc: 0.625000
# Test Loss:0.692834, Acc: 0.500000
# Train43 epoch, Loss: 0.692864, Acc: 0.562500
# Test Loss:0.692827, Acc: 0.500000
# Train44 epoch, Loss: 0.693161, Acc: 0.375000
# Test Loss:0.692821, Acc: 0.500000
# Train45 epoch, Loss: 0.693319, Acc: 0.625000
# Test Loss:0.692815, Acc: 0.500000
# Train46 epoch, Loss: 0.692396, Acc: 0.750000
# Test Loss:0.692808, Acc: 0.500000
# Train47 epoch, Loss: 0.693465, Acc: 0.500000
# Test Loss:0.692801, Acc: 0.500000
# Train48 epoch, Loss: 0.692730, Acc: 0.625000
# Test Loss:0.692795, Acc: 0.500000
# Train49 epoch, Loss: 0.692374, Acc: 0.562500
# Test Loss:0.692788, Acc: 0.500000
# Train50 epoch, Loss: 0.692494, Acc: 0.625000
# Test Loss:0.692782, Acc: 0.500000

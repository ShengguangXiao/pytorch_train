# %%
import torch
from torchvision import transforms
from PIL import Image

# %%
image = Image.open('./data/829821.png')
image = image.convert('L')
image
# Out:
# <PIL.Image.Image image mode=L size=595x639 at 0x11239AFD0>
